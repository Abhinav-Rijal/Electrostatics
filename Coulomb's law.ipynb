# %% [markdown]
# ## Coulomb's Law
# Coulomb's force between two point charged particles is given by:
# $$ \vec{F}=k\frac{q_1q_2}{r^2}\hat{r} $$
#
# where;
#
# $q_1$= point charge taken at origin '$O$'
#
# $q_2$= point charge(test charge) taken at a distance '$r$' from $q_1$
#
# $\vec{r}$= position vector of $q_2$
#
# $\hat{r}$= $\frac{\vec{r}}{r}$ = unit vector(outward radial) along the position vector of $q_2$
#
# and the magnitude of the force is;
# $$ F= k\frac{q_1q_2}{r^2} $$
#
# The electric field intensity of pt. charge '$q_1$' at a point at distance '$r$' from it is defined as;
#
# $$ \vec{E}=\frac{\vec{F}}{q_2}=k\frac{q_1}{r^2}\hat{r} $$
#
# Again, the magnitude of electric field intensity is;
# $$ E=k\frac{q_1}{r^2} $$
#
# And the electric potential of pt. charge '$q_1$' at a point at distance '$r$' from it is;
# $$ V=k\frac{q_1}{r} $$
# Now, for a given $q_1$ and $q_2$, the locus of points for which the magnitudes of force and intensity and value of potential i.e $F, E, V$ are constant is given by;
#
# $r$=constant
#
# Or, $r^2$=constant
#
# or, $x^2+y^2$=constant, where $\vec{r}=(x,y)$ in 2-D plane space $R^2$
#
# Which is the equation of a circle in 2-D plane space $R^2$. Since for magnitudes, there's no directivity property, there's no solution for angle i.e from $0$ to $2\pi$ for the given $r$, thus giving a circle (Equipotential curve) or a sphere (Equipotential surface, in 3-D).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
class Coulomb():
    def __init__(self,k,q1,q2):
        self.k=k
        self.q1=q1
        self.q2=q2
    def Force(self,r):
        return self.k*self.q1*self.q2/r**2
    def Intensity(self,r):
        return self.k*self.q1/r**2
    def Potential(self,r):
        return self.k*self.q1/r
    def test_q1(self):
        return self.q1
    def update_charge(self,q1,q2):
        self.q1=q1
        self.q2=q2

# %%
C1=Coulomb(k=9*10e9, q1=10e-6, q2=10e-4)
f=C1.Force(10)
e=C1.Intensity(10)
v=C1.Potential(10)
print('The force, intensity and potential are:')
print(f),print(e),print(v)
# Out:
# The force, intensity and potential are:
# 9.000000000000002
# 9000.000000000002
# 90000.00000000001
# (None, None, None)

# %%
C=Coulomb(9*10e9,0,0) #initialize object C of class Coulomb with arguments 0,0,0
print(C.test_q1())
q1=9 #doesn't take this value
print(C.test_q1())
# Out:
# 0
# 0

# %%
#to update data of class(q1,q2), we have defined update function in Coulomb
C.update_charge(9,9)
print(C.test_q1())
# Out:
# 9

# %%
C.update_charge(3.2e-6,3.2e-10)
#print(C.test_q1())
R=[] #empty list to collect distances
F=[] #empty list to collect forces
E=[] #empty list to collect intensities
V=[] #empty list to collect potentials
for r in range(1,1000):
    f=C.Force(r)
    e=C.Intensity(r)
    v=C.Potential(r)
    R.append(r)
    F.append(f)
    E.append(e)
    V.append(v)
    
plt.figure(figsize=[9,9])

plt.subplot(2,2,1)
plt.plot(R,F,label='force')
plt.xlabel('r')
plt.ylabel('F,E,V')
plt.plot(R,E,label='intensity')
plt.plot(R,V,label='potential')
plt.title('Normal scale')
plt.legend()

plt.subplot(2,2,2)
plt.semilogy(R,F,label='force')
plt.xlabel('r')
plt.ylabel('F,E,V')
plt.semilogy(R,E,label='intensity')
plt.semilogy(R,V,label='potential')
plt.title('Semilog scale')
plt.legend()

plt.subplot(2,2,3)
plt.loglog(R,F,label='force')
plt.xlabel('r')
plt.ylabel('F,E,V')
plt.loglog(R,E,label='intensity')
plt.loglog(R,V,label='potential')
plt.title('loglog scale')
plt.legend()

# %%
#making r as class variable
class Coulomb():
    def __init__(self,k,q1,q2,r):
        self.k=k
        self.q1=q1
        self.q2=q2
        self.r=r
    def Force(self):
        return self.k*self.q1*self.q2/self.r**2
    def Intensity(self):
        return self.k*self.q1/self.r**2
    def Potential(self):
        return self.k*self.q1/self.r
    def update_r(self,r):
        self.r=r
    def update_charge(self,q1,q2):
        self.q1=q1
        self.q2=q2

# %%
C=Coulomb(9*10e9,0,0,0)
C.update_charge(3.2e-6,3.2e-10)
#print(C.test_q1())
R=[] #empty list to collect distances
F=[] #empty list to collect forces
E=[] #empty list to collect intensities
V=[] #empty list to collect potentials
for r in range(1,1000):
    C.update_r(r)
    f=C.Force()
    e=C.Intensity()
    v=C.Potential()
    R.append(r)
    F.append(f)
    E.append(e)
    V.append(v)
    
plt.figure(figsize=[9,9])

plt.subplot(2,2,1)
plt.plot(R,F,label='force')
plt.xlabel('r')
plt.ylabel('F,E,V')
plt.plot(R,E,label='intensity')
plt.plot(R,V,label='potential')
plt.title('Normal scale')
plt.legend()

plt.subplot(2,2,2)
plt.semilogy(R,F,label='force')
plt.xlabel('r')
plt.ylabel('F,E,V')
plt.semilogy(R,E,label='intensity')
plt.semilogy(R,V,label='potential')
plt.title('Semilog scale')
plt.legend()

plt.subplot(2,2,3)
plt.loglog(R,F,label='force')
plt.xlabel('r')
plt.ylabel('F,E,V')
plt.loglog(R,E,label='intensity')
plt.loglog(R,V,label='potential')
plt.title('loglog scale')
plt.legend()

# %%
data={} #empty dictionary
data.update({"Distance":R,"Force":F,"Intensity":E,"Potential":V})
#print(data)

# %%
Df=pd.DataFrame(data)
print(Df)
# Out:
#      Distance         Force      Intensity      Potential
# 0           1  9.216000e-05  288000.000000  288000.000000
# 1           2  2.304000e-05   72000.000000  144000.000000
# 2           3  1.024000e-05   32000.000000   96000.000000
# 3           4  5.760000e-06   18000.000000   72000.000000
# 4           5  3.686400e-06   11520.000000   57600.000000
# 5           6  2.560000e-06    8000.000000   48000.000000
# 6           7  1.880816e-06    5877.551020   41142.857143
# 7           8  1.440000e-06    4500.000000   36000.000000
# 8           9  1.137778e-06    3555.555556   32000.000000
# 9          10  9.216000e-07    2880.000000   28800.000000
# 10         11  7.616529e-07    2380.165289   26181.818182
# 11         12  6.400000e-07    2000.000000   24000.000000
# 12         13  5.453254e-07    1704.142012   22153.846154
# 13         14  4.702041e-07    1469.387755   20571.428571
# 14         15  4.096000e-07    1280.000000   19200.000000
# 15         16  3.600000e-07    1125.000000   18000.000000
# 16         17  3.188927e-07     996.539792   16941.176471
# 17         18  2.844444e-07     888.888889   16000.000000
# 18         19  2.552909e-07     797.783934   15157.894737
# 19         20  2.304000e-07     720.000000   14400.000000
# 20         21  2.089796e-07     653.061224   13714.285714
# 21         22  1.904132e-07     595.041322   13090.909091
# 22         23  1.742155e-07     544.423440   12521.739130
# 23         24  1.600000e-07     500.000000   12000.000000
# 24         25  1.474560e-07     460.800000   11520.000000
# 25         26  1.363314e-07     426.035503   11076.923077
# 26         27  1.264198e-07     395.061728   10666.666667
# 27         28  1.175510e-07     367.346939   10285.714286
# 28         29  1.095838e-07     342.449465    9931.034483
# 29         30  1.024000e-07     320.000000    9600.000000
# ..        ...           ...            ...            ...
# 969       970  9.794877e-11       0.306090     296.907216
# 970       971  9.774713e-11       0.305460     296.601442
# 971       972  9.754611e-11       0.304832     296.296296
# 972       973  9.734570e-11       0.304205     295.991778
# 973       974  9.714592e-11       0.303581     295.687885
# 974       975  9.694675e-11       0.302959     295.384615
# 975       976  9.674819e-11       0.302338     295.081967
# 976       977  9.655024e-11       0.301719     294.779939
# 977       978  9.635289e-11       0.301103     294.478528
# 978       979  9.615615e-11       0.300488     294.177732
# 979       980  9.596002e-11       0.299875     293.877551
# 980       981  9.576448e-11       0.299264     293.577982
# 981       982  9.556954e-11       0.298655     293.279022
# 982       983  9.537519e-11       0.298047     292.980671
# 983       984  9.518144e-11       0.297442     292.682927
# 984       985  9.498828e-11       0.296838     292.385787
# 985       986  9.479570e-11       0.296237     292.089249
# 986       987  9.460371e-11       0.295637     291.793313
# 987       988  9.441230e-11       0.295038     291.497976
# 988       989  9.422147e-11       0.294442     291.203236
# 989       990  9.403122e-11       0.293848     290.909091
# 990       991  9.384155e-11       0.293255     290.615540
# 991       992  9.365245e-11       0.292664     290.322581
# 992       993  9.346392e-11       0.292075     290.030211
# 993       994  9.327595e-11       0.291487     289.738431
# 994       995  9.308856e-11       0.290902     289.447236
# 995       996  9.290173e-11       0.290318     289.156627
# 996       997  9.271546e-11       0.289736     288.866600
# 997       998  9.252975e-11       0.289155     288.577154
# 998       999  9.234460e-11       0.288577     288.288288
#
# [999 rows x 4 columns]

# %%
#create .csv(excel) file
Df.to_csv('FEV.csv')

# %%
#reading .csv file and plotting its column ve column
df1=pd.read_csv('FEV.csv')
df1.head() #display function
# Out:
#    Unnamed: 0  Distance     Force  Intensity  Potential
# 0           0         1  0.000092   288000.0   288000.0
# 1           1         2  0.000023    72000.0   144000.0
# 2           2         3  0.000010    32000.0    96000.0
# 3           3         4  0.000006    18000.0    72000.0
# 4           4         5  0.000004    11520.0    57600.0

# %%
plt.semilogy(df1.Distance,df1.Force)

# %%
plt.semilogy(df1.Distance,df1.Intensity)

# %%
plt.semilogy(df1.Distance,df1.Potential)

# %%
plt.semilogy(df1.Distance,df1.Force,'r')
plt.semilogy(df1.Distance,df1.Intensity,'g')
plt.semilogy(df1.Distance,df1.Potential,'b')

# %%
plt.loglog(df1.Distance,df1.Force,'r')
plt.loglog(df1.Distance,df1.Intensity,'g')
plt.loglog(df1.Distance,df1.Potential,'b')
